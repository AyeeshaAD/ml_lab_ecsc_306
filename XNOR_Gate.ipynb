# %%
import tensorflow as tf
sess = tf.InteractiveSession()

x_ = [[0, 0], [0, 1], [1, 0], [1, 1]] # input
#labels=[1,      0,      0,      1]   # output =>
expect=[[0,1],  [1,0],  [1,0], [0,1]] #REPRESENTATION! 'class' [1,0]==0 [0,1]==1


x = tf.placeholder("float", [None,2]) 
y_ = tf.placeholder("float", [None, 2]) 

number_hidden_nodes = 20 

W = tf.Variable(tf.random_uniform([2, number_hidden_nodes], -.01, .01))
b = tf.Variable(tf.random_uniform([number_hidden_nodes], -.01, .01))
hidden  = tf.nn.relu(tf.matmul(x,W) + b) 

 
W2 = tf.Variable(tf.random_uniform([number_hidden_nodes,2], -.1, .1))
b2 = tf.Variable(tf.zeros([2]))
hidden2 = tf.matmul(hidden, W2)#+b2

y = tf.nn.softmax(hidden2)


cross_entropy = -tf.reduce_sum(y_*tf.log(y))
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(cross_entropy)


tf.initialize_all_variables().run()
for step in range(1000):
    feed_dict={x: x_, y_:expect } 
    e,a=sess.run([cross_entropy,train_step],feed_dict)
    if e<1:break 
    print ("step %d : entropy %s" % (step,e))


correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1)) 
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float")) 

print ("accuracy %s"%(accuracy.eval({x: x_, y_: expect})))

learned_output=tf.argmax(y,1)
print (learned_output.eval({x: x_}))
# Out:
# WARNING:tensorflow:From /home/ise/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# step 0 : entropy 2.77257
# step 1 : entropy 2.77171
# step 2 : entropy 2.77059
# step 3 : entropy 2.77101
# step 4 : entropy 2.76814
# step 5 : entropy 2.76664
# step 6 : entropy 2.76727
# step 7 : entropy 2.76324
# step 8 : entropy 2.76205
# step 9 : entropy 2.76162
# step 10 : entropy 2.75713
# step 11 : entropy 2.75465
# step 12 : entropy 2.75432
# step 13 : entropy 2.74688
# step 14 : entropy 2.74451
# step 15 : entropy 2.74192
# step 16 : entropy 2.73241
# step 17 : entropy 2.72746
# step 18 : entropy 2.7244
# step 19 : entropy 2.70867
# step 20 : entropy 2.70227
# step 21 : entropy 2.6957
# step 22 : entropy 2.67421
# step 23 : entropy 2.66197
# step 24 : entropy 2.6543
# step 25 : entropy 2.6226
# step 26 : entropy 2.59899
# step 27 : entropy 2.5937
# step 28 : entropy 2.54492
# step 29 : entropy 2.51245
# step 30 : entropy 2.4992
# step 31 : entropy 2.45328
# step 32 : entropy 2.36323
# step 33 : entropy 2.40053
# step 34 : entropy 2.30717
# step 35 : entropy 2.23798
# step 36 : entropy 2.19102
# step 37 : entropy 2.09072
# step 38 : entropy 2.07141
# step 39 : entropy 2.05028
# step 40 : entropy 1.90956
# step 41 : entropy 1.88803
# step 42 : entropy 1.85194
# step 43 : entropy 1.75798
# step 44 : entropy 1.64879
# step 45 : entropy 1.62798
# step 46 : entropy 1.6097
# step 47 : entropy 1.51446
# step 48 : entropy 1.39679
# step 49 : entropy 1.37795
# step 50 : entropy 1.31898
# step 51 : entropy 1.22794
# step 52 : entropy 1.26797
# step 53 : entropy 1.16067
# step 54 : entropy 1.08451
# step 55 : entropy 1.01838
# accuracy 1.0
# [1 0 0 1]
